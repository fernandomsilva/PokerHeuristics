# %%
import pyximport; pyximport.install()
from csvparser import *
from gpcode import *

# %%
csv_filename = "AAS Results/mapping-" + machine_alias + ".csv.txt"

fields = [['EndTree'], ['Fitness']]
conditions = []

csv_data = extractDictFromCSV(csv_filename)
parsed_data = extractIndividualsFromAASData(csv_data, ind_field=fields[0], fitness_field=fields[1], condition=conditions)
parsed_data = sorted(parsed_data, reverse=True)

# %%
top = topK(parsed_data, 10)
for t in parsed_data:
    if findComplexity(gp.PrimitiveTree.from_string(t.heuristic, pset)) == 8:
        print t.heuristic
        print t.fitness
# Out:
# IfThenElse(isSameSuit(ARG0), 'check', IfThenElse(highestCardLE(ARG0, 10), 'check', IfThenElse(and_(totalPotLE(ARG1, 3), totalPotLE(ARG1, 1)), 'raise', 'check')))
# 0.201575
# IfThenElse(highestCardLE(ARG0, 10), 'check', IfThenElse(and_(totalPotGE(ARG1, 2), cardDifferenceLE(ARG0, 10)), 'check', IfThenElse(highestCardGE(ARG0, 14), 'check', 'raise')))
# -0.10045
# IfThenElse(lowestCardLE(ARG0, 2), 'check', IfThenElse(and_(highestCardLE(ARG0, 11), cardDifferenceLE(ARG0, 4)), 'check', IfThenElse(lowestCardGE(ARG0, 11), 'raise', 'check')))
# -0.1144
# IfThenElse(lowestCardLE(ARG0, 8), 'check', IfThenElse(lowestCardGE(ARG0, 10), 'raise', IfThenElse(and_(totalPotGE(ARG1, 25), highestCardLE(ARG0, 12)), 'fold', 'check')))
# -0.166475
# IfThenElse(lowestCardLE(ARG0, 7), 'check', IfThenElse(hasDoubles(ARG0), 'raise', IfThenElse(and_(totalPotGE(ARG1, 26), highestCardGE(ARG0, 11)), 'fold', 'check')))
# -0.203125
# IfThenElse(lowestCardGE(ARG0, 10), 'raise', IfThenElse(and_(isSameSuit(ARG0), isSameSuit(ARG0)), 'check', IfThenElse(highestCardLE(ARG0, 2), 'raise', 'check')))
# -0.213025
# IfThenElse(and_(hasDoubles(ARG0), lowestCardGE(ARG0, 3)), 'raise', IfThenElse(isSameSuit(ARG0), 'check', IfThenElse(totalPotGE(ARG1, 16), 'raise', 'check')))
# -0.235425
# IfThenElse(hasDoubles(ARG0), 'raise', IfThenElse(highestCardGE(ARG0, 14), 'check', IfThenElse(and_(totalPotGE(ARG1, 1), lowestCardLE(ARG0, 11)), 'check', 'raise')))
# -0.2837
# IfThenElse(isSameSuit(ARG0), 'check', IfThenElse(lowestCardLE(ARG0, 2), 'check', IfThenElse(and_(lowestCardGE(ARG0, 2), lowestCardLE(ARG0, 10)), 'check', 'raise')))
# -0.302775
# IfThenElse(cardDifferenceGE(ARG0, 2), 'check', IfThenElse(and_(cardDifferenceLE(ARG0, 11), lowestCardLE(ARG0, 7)), 'check', IfThenElse(totalPotGE(ARG1, 1), 'raise', 'fold')))
# -0.335575
# IfThenElse(and_(lowestCardGE(ARG0, 2), cardDifferenceGE(ARG0, 5)), 'check', IfThenElse(highestCardGE(ARG0, 14), 'raise', IfThenElse(highestCardGE(ARG0, 3), 'check', 'fold')))
# -0.34305
# IfThenElse(isSameSuit(ARG0), 'check', IfThenElse(lowestCardGE(ARG0, 9), 'raise', IfThenElse(and_(totalPotGE(ARG1, 10), cardDifferenceLE(ARG0, 11)), 'fold', 'check')))
# -0.350325
# IfThenElse(cardDifferenceGE(ARG0, 3), 'check', IfThenElse(isSameSuit(ARG0), 'check', IfThenElse(and_(lowestCardGE(ARG0, 11), lowestCardLE(ARG0, 14)), 'raise', 'check')))
# -0.3514
# IfThenElse(hasDoubles(ARG0), 'raise', IfThenElse(highestCardLE(ARG0, 8), 'check', IfThenElse(and_(highestCardGE(ARG0, 2), highestCardLE(ARG0, 13)), 'check', 'raise')))
# -0.3791
# IfThenElse(isSameSuit(ARG0), 'check', IfThenElse(hasDoubles(ARG0), 'raise', IfThenElse(and_(cardDifferenceLE(ARG0, 10), highestCardLE(ARG0, 13)), 'check', 'raise')))
# -0.42645
# IfThenElse(totalPotLE(ARG1, 1), 'check', IfThenElse(cardDifferenceGE(ARG0, 12), 'raise', IfThenElse(and_(hasDoubles(ARG0), lowestCardGE(ARG0, 4)), 'raise', 'check')))
# -0.462275
# IfThenElse(and_(cardDifferenceGE(ARG0, 10), cardDifferenceLE(ARG0, 12)), 'check', IfThenElse(lowestCardGE(ARG0, 10), 'raise', IfThenElse(cardDifferenceLE(ARG0, 8), 'check', 'raise')))
# -0.5126
# IfThenElse(totalPotLE(ARG1, 4), 'check', IfThenElse(and_(isSameSuit(ARG0), isSameSuit(ARG0)), 'fold', IfThenElse(highestCardLE(ARG0, 3), 'check', 'raise')))
# -0.52215
# IfThenElse(and_(isSameSuit(ARG0), cardDifferenceLE(ARG0, 9)), 'check', IfThenElse(lowestCardLE(ARG0, 11), 'check', IfThenElse(hasDoubles(ARG0), 'check', 'raise')))
# -0.581375
# IfThenElse(totalPotGE(ARG1, 3), 'fold', IfThenElse(lowestCardLE(ARG0, 10), 'check', IfThenElse(and_(cardDifferenceLE(ARG0, 8), lowestCardLE(ARG0, 4)), 'fold', 'raise')))
# -0.585325
# IfThenElse(cardDifferenceGE(ARG0, 2), 'check', IfThenElse(and_(highestCardGE(ARG0, 9), isSameSuit(ARG0)), 'check', IfThenElse(lowestCardLE(ARG0, 5), 'check', 'raise')))
# -0.586025
# IfThenElse(totalPotLE(ARG1, 6), 'check', IfThenElse(isSameSuit(ARG0), 'check', IfThenElse(and_(highestCardLE(ARG0, 9), cardDifferenceGE(ARG0, 3)), 'check', 'fold')))
# -0.58875
# IfThenElse(totalPotLE(ARG1, 24), 'check', IfThenElse(and_(totalPotLE(ARG1, 5), lowestCardGE(ARG0, 8)), 'fold', IfThenElse(totalPotLE(ARG1, 26), 'check', 'check')))
# -0.609475
# IfThenElse(and_(lowestCardGE(ARG0, 13), lowestCardGE(ARG0, 13)), 'check', IfThenElse(cardDifferenceLE(ARG0, 14), 'check', IfThenElse(hasDoubles(ARG0), 'fold', 'fold')))
# -0.63475
# IfThenElse(totalPotLE(ARG1, 21), 'check', IfThenElse(and_(highestCardGE(ARG0, 5), cardDifferenceLE(ARG0, 6)), 'raise', IfThenElse(cardDifferenceGE(ARG0, 12), 'raise', 'check')))
# -0.63815
# IfThenElse(and_(highestCardGE(ARG0, 10), highestCardLE(ARG0, 14)), 'check', IfThenElse(highestCardGE(ARG0, 4), 'check', IfThenElse(hasDoubles(ARG0), 'check', 'fold')))
# -0.6403
# IfThenElse(isSameSuit(ARG0), 'check', IfThenElse(and_(highestCardLE(ARG0, 2), cardDifferenceLE(ARG0, 7)), 'raise', IfThenElse(cardDifferenceLE(ARG0, 11), 'check', 'raise')))
# -0.642975
# IfThenElse(highestCardGE(ARG0, 5), 'check', IfThenElse(and_(highestCardLE(ARG0, 7), highestCardGE(ARG0, 4)), 'check', IfThenElse(highestCardLE(ARG0, 2), 'raise', 'check')))
# -0.64755
# IfThenElse(and_(cardDifferenceLE(ARG0, 4), highestCardLE(ARG0, 14)), 'check', IfThenElse(highestCardGE(ARG0, 10), 'check', IfThenElse(highestCardLE(ARG0, 7), 'fold', 'check')))
# -0.656225
# IfThenElse(isSameSuit(ARG0), 'check', IfThenElse(and_(totalPotLE(ARG1, 23), highestCardGE(ARG0, 2)), 'check', IfThenElse(totalPotLE(ARG1, 19), 'check', 'fold')))
# -0.657825
# IfThenElse(and_(highestCardLE(ARG0, 13), highestCardGE(ARG0, 4)), 'check', IfThenElse(lowestCardLE(ARG0, 2), 'check', IfThenElse(highestCardGE(ARG0, 12), 'check', 'raise')))
# -0.66795
# IfThenElse(highestCardLE(ARG0, 5), 'check', IfThenElse(cardDifferenceLE(ARG0, 4), 'check', IfThenElse(and_(isSameSuit(ARG0), totalPotGE(ARG1, 2)), 'check', 'check')))
# -0.670075
# IfThenElse(and_(isSameSuit(ARG0), highestCardGE(ARG0, 7)), 'check', IfThenElse(isSameSuit(ARG0), 'check', IfThenElse(totalPotGE(ARG1, 3), 'raise', 'check')))
# -0.6743
# IfThenElse(highestCardLE(ARG0, 2), 'fold', IfThenElse(and_(highestCardGE(ARG0, 2), highestCardGE(ARG0, 5)), 'check', IfThenElse(lowestCardLE(ARG0, 2), 'fold', 'check')))
# -0.6932
# IfThenElse(highestCardGE(ARG0, 4), 'check', IfThenElse(and_(lowestCardLE(ARG0, 2), highestCardLE(ARG0, 11)), 'check', IfThenElse(totalPotLE(ARG1, 28), 'fold', 'check')))
# -0.693375
# IfThenElse(cardDifferenceGE(ARG0, 11), 'check', IfThenElse(and_(cardDifferenceGE(ARG0, 2), highestCardLE(ARG0, 12)), 'check', IfThenElse(lowestCardGE(ARG0, 3), 'check', 'fold')))
# -0.704525
# IfThenElse(cardDifferenceLE(ARG0, 2), 'check', IfThenElse(and_(cardDifferenceLE(ARG0, 8), lowestCardGE(ARG0, 11)), 'check', IfThenElse(totalPotGE(ARG1, 26), 'raise', 'check')))
# -0.710775
# IfThenElse(lowestCardGE(ARG0, 8), 'raise', IfThenElse(cardDifferenceLE(ARG0, 8), 'check', IfThenElse(and_(totalPotGE(ARG1, 1), totalPotLE(ARG1, 13)), 'check', 'raise')))
# -0.745675
# IfThenElse(lowestCardGE(ARG0, 3), 'check', IfThenElse(highestCardLE(ARG0, 8), 'check', IfThenElse(and_(highestCardLE(ARG0, 14), cardDifferenceGE(ARG0, 8)), 'check', 'raise')))
# -0.783525
# IfThenElse(and_(highestCardLE(ARG0, 5), cardDifferenceLE(ARG0, 6)), 'fold', IfThenElse(hasDoubles(ARG0), 'raise', IfThenElse(lowestCardGE(ARG0, 14), 'fold', 'check')))
# -0.85745
# IfThenElse(and_(cardDifferenceLE(ARG0, 13), highestCardLE(ARG0, 11)), 'check', IfThenElse(highestCardGE(ARG0, 14), 'check', IfThenElse(lowestCardLE(ARG0, 2), 'raise', 'check')))
# -0.876225
# IfThenElse(highestCardGE(ARG0, 4), 'check', IfThenElse(highestCardGE(ARG0, 6), 'check', IfThenElse(and_(lowestCardLE(ARG0, 14), isSameSuit(ARG0)), 'fold', 'raise')))
# -0.87965
# IfThenElse(and_(lowestCardGE(ARG0, 6), totalPotGE(ARG1, 9)), 'raise', IfThenElse(lowestCardGE(ARG0, 3), 'check', IfThenElse(totalPotLE(ARG1, 1), 'raise', 'check')))
# -0.911175
# IfThenElse(totalPotGE(ARG1, 13), 'raise', IfThenElse(and_(totalPotLE(ARG1, 17), lowestCardLE(ARG0, 7)), 'check', IfThenElse(totalPotLE(ARG1, 28), 'raise', 'check')))
# -0.95265
# IfThenElse(cardDifferenceGE(ARG0, 4), 'check', IfThenElse(hasDoubles(ARG0), 'raise', IfThenElse(and_(cardDifferenceGE(ARG0, 2), highestCardGE(ARG0, 2)), 'check', 'raise')))
# -1.121525
# IfThenElse(and_(cardDifferenceLE(ARG0, 7), cardDifferenceGE(ARG0, 10)), 'check', IfThenElse(lowestCardLE(ARG0, 3), 'check', IfThenElse(hasDoubles(ARG0), 'fold', 'check')))
# -1.8504
# IfThenElse(totalPotGE(ARG1, 3), 'fold', IfThenElse(highestCardGE(ARG0, 9), 'check', IfThenElse(and_(hasDoubles(ARG0), totalPotGE(ARG1, 21)), 'fold', 'raise')))
# -2.253325
# IfThenElse(totalPotGE(ARG1, 5), 'fold', IfThenElse(and_(cardDifferenceLE(ARG0, 4), cardDifferenceGE(ARG0, 3)), 'raise', IfThenElse(lowestCardLE(ARG0, 13), 'raise', 'check')))
# -3.2775
# IfThenElse(cardDifferenceGE(ARG0, 13), 'fold', IfThenElse(and_(cardDifferenceGE(ARG0, 13), totalPotGE(ARG1, 2)), 'fold', IfThenElse(totalPotGE(ARG1, 5), 'fold', 'raise')))
# -3.317825
# IfThenElse(and_(totalPotLE(ARG1, 23), highestCardGE(ARG0, 14)), 'fold', IfThenElse(lowestCardLE(ARG0, 10), 'check', IfThenElse(totalPotLE(ARG1, 26), 'raise', 'check')))
# -3.35015
# IfThenElse(cardDifferenceGE(ARG0, 5), 'fold', IfThenElse(and_(highestCardGE(ARG0, 13), totalPotGE(ARG1, 1)), 'raise', IfThenElse(highestCardGE(ARG0, 10), 'check', 'check')))
# -5.9032
# IfThenElse(totalPotGE(ARG1, 24), 'raise', IfThenElse(highestCardLE(ARG0, 8), 'fold', IfThenElse(and_(lowestCardLE(ARG0, 9), lowestCardGE(ARG0, 7)), 'fold', 'check')))
# -6.22015
# IfThenElse(hasDoubles(ARG0), 'check', IfThenElse(and_(highestCardLE(ARG0, 12), highestCardGE(ARG0, 6)), 'raise', IfThenElse(hasDoubles(ARG0), 'raise', 'check')))
# -6.492825
# IfThenElse(lowestCardGE(ARG0, 3), 'raise', IfThenElse(isSameSuit(ARG0), 'raise', IfThenElse(and_(lowestCardLE(ARG0, 2), lowestCardLE(ARG0, 14)), 'check', 'raise')))
# -6.546475
# IfThenElse(and_(isSameSuit(ARG0), hasDoubles(ARG0)), 'raise', IfThenElse(highestCardLE(ARG0, 2), 'fold', IfThenElse(highestCardGE(ARG0, 8), 'raise', 'fold')))
# -6.810025
# IfThenElse(highestCardGE(ARG0, 11), 'check', IfThenElse(and_(highestCardGE(ARG0, 3), cardDifferenceGE(ARG0, 9)), 'raise', IfThenElse(hasDoubles(ARG0), 'fold', 'raise')))
# -6.84125
# IfThenElse(isSameSuit(ARG0), 'raise', IfThenElse(lowestCardGE(ARG0, 14), 'check', IfThenElse(and_(cardDifferenceLE(ARG0, 13), totalPotLE(ARG1, 26)), 'raise', 'fold')))
# -7.821125
# IfThenElse(highestCardLE(ARG0, 14), 'raise', IfThenElse(lowestCardGE(ARG0, 11), 'check', IfThenElse(and_(highestCardGE(ARG0, 11), cardDifferenceGE(ARG0, 12)), 'raise', 'raise')))
# -7.87725
# IfThenElse(cardDifferenceLE(ARG0, 13), 'raise', IfThenElse(and_(isSameSuit(ARG0), hasDoubles(ARG0)), 'check', IfThenElse(isSameSuit(ARG0), 'check', 'fold')))
# -8.099975
# IfThenElse(highestCardGE(ARG0, 3), 'raise', IfThenElse(and_(cardDifferenceGE(ARG0, 5), lowestCardLE(ARG0, 12)), 'check', IfThenElse(cardDifferenceLE(ARG0, 8), 'raise', 'raise')))
# -8.1266
# IfThenElse(isSameSuit(ARG0), 'raise', IfThenElse(and_(lowestCardLE(ARG0, 13), lowestCardLE(ARG0, 13)), 'raise', IfThenElse(lowestCardGE(ARG0, 7), 'raise', 'raise')))
# -8.18535
# IfThenElse(and_(lowestCardGE(ARG0, 10), cardDifferenceLE(ARG0, 7)), 'check', IfThenElse(lowestCardGE(ARG0, 11), 'fold', IfThenElse(lowestCardGE(ARG0, 13), 'check', 'raise')))
# -8.30745
# IfThenElse(cardDifferenceGE(ARG0, 12), 'fold', IfThenElse(lowestCardLE(ARG0, 7), 'raise', IfThenElse(and_(highestCardGE(ARG0, 9), totalPotLE(ARG1, 16)), 'raise', 'raise')))
# -8.342075
# IfThenElse(highestCardGE(ARG0, 13), 'check', IfThenElse(and_(lowestCardLE(ARG0, 3), cardDifferenceGE(ARG0, 12)), 'raise', IfThenElse(lowestCardLE(ARG0, 13), 'fold', 'fold')))
# -8.401475
# IfThenElse(cardDifferenceLE(ARG0, 10), 'raise', IfThenElse(totalPotLE(ARG1, 1), 'fold', IfThenElse(and_(lowestCardGE(ARG0, 14), totalPotLE(ARG1, 1)), 'raise', 'raise')))
# -8.4165
# IfThenElse(lowestCardGE(ARG0, 8), 'fold', IfThenElse(and_(totalPotLE(ARG1, 22), hasDoubles(ARG0)), 'check', IfThenElse(cardDifferenceLE(ARG0, 3), 'raise', 'check')))
# -8.82485
# IfThenElse(lowestCardGE(ARG0, 6), 'fold', IfThenElse(and_(isSameSuit(ARG0), hasDoubles(ARG0)), 'raise', IfThenElse(cardDifferenceGE(ARG0, 2), 'check', 'fold')))
# -9.144275
# IfThenElse(and_(isSameSuit(ARG0), totalPotLE(ARG1, 23)), 'check', IfThenElse(cardDifferenceLE(ARG0, 7), 'fold', IfThenElse(isSameSuit(ARG0), 'fold', 'raise')))
# -9.55835
# IfThenElse(and_(totalPotLE(ARG1, 6), cardDifferenceGE(ARG0, 6)), 'raise', IfThenElse(cardDifferenceLE(ARG0, 5), 'fold', IfThenElse(highestCardLE(ARG0, 6), 'raise', 'check')))
# -9.83315
# IfThenElse(totalPotGE(ARG1, 9), 'raise', IfThenElse(lowestCardLE(ARG0, 10), 'raise', IfThenElse(and_(isSameSuit(ARG0), cardDifferenceLE(ARG0, 6)), 'raise', 'fold')))
# -9.8937
# IfThenElse(highestCardLE(ARG0, 6), 'raise', IfThenElse(and_(isSameSuit(ARG0), totalPotLE(ARG1, 29)), 'check', IfThenElse(highestCardLE(ARG0, 9), 'check', 'fold')))
# -10.034425
# IfThenElse(totalPotGE(ARG1, 28), 'raise', IfThenElse(cardDifferenceLE(ARG0, 2), 'fold', IfThenElse(and_(cardDifferenceLE(ARG0, 4), lowestCardGE(ARG0, 3)), 'check', 'fold')))
# -11.08075
# IfThenElse(cardDifferenceGE(ARG0, 9), 'check', IfThenElse(and_(cardDifferenceLE(ARG0, 3), totalPotGE(ARG1, 13)), 'check', IfThenElse(cardDifferenceLE(ARG0, 2), 'fold', 'fold')))
# -11.92425
# IfThenElse(cardDifferenceLE(ARG0, 8), 'fold', IfThenElse(and_(cardDifferenceGE(ARG0, 14), lowestCardLE(ARG0, 10)), 'fold', IfThenElse(cardDifferenceLE(ARG0, 3), 'check', 'check')))
# -11.968275
# IfThenElse(and_(totalPotLE(ARG1, 21), totalPotGE(ARG1, 26)), 'raise', IfThenElse(isSameSuit(ARG0), 'raise', IfThenElse(lowestCardLE(ARG0, 3), 'fold', 'fold')))
# -11.97575
# IfThenElse(isSameSuit(ARG0), 'raise', IfThenElse(and_(totalPotGE(ARG1, 13), lowestCardLE(ARG0, 7)), 'raise', IfThenElse(isSameSuit(ARG0), 'check', 'fold')))
# -12.021
# IfThenElse(cardDifferenceLE(ARG0, 8), 'fold', IfThenElse(and_(lowestCardLE(ARG0, 14), totalPotGE(ARG1, 13)), 'check', IfThenElse(isSameSuit(ARG0), 'raise', 'raise')))
# -12.287375
# IfThenElse(and_(cardDifferenceLE(ARG0, 3), totalPotGE(ARG1, 4)), 'check', IfThenElse(lowestCardGE(ARG0, 3), 'fold', IfThenElse(lowestCardGE(ARG0, 11), 'fold', 'check')))
# -12.445625
# IfThenElse(cardDifferenceLE(ARG0, 9), 'fold', IfThenElse(and_(totalPotLE(ARG1, 22), highestCardLE(ARG0, 14)), 'check', IfThenElse(totalPotGE(ARG1, 17), 'fold', 'check')))
# -12.62955
# IfThenElse(cardDifferenceGE(ARG0, 9), 'raise', IfThenElse(and_(highestCardLE(ARG0, 6), cardDifferenceGE(ARG0, 5)), 'fold', IfThenElse(highestCardLE(ARG0, 11), 'fold', 'fold')))
# -12.769075
# IfThenElse(and_(cardDifferenceGE(ARG0, 13), cardDifferenceGE(ARG0, 12)), 'check', IfThenElse(highestCardLE(ARG0, 14), 'fold', IfThenElse(highestCardGE(ARG0, 7), 'check', 'raise')))
# -13.6821
# IfThenElse(cardDifferenceLE(ARG0, 7), 'fold', IfThenElse(lowestCardLE(ARG0, 11), 'fold', IfThenElse(and_(lowestCardLE(ARG0, 10), hasDoubles(ARG0)), 'fold', 'raise')))
# -13.684425
# IfThenElse(totalPotLE(ARG1, 2), 'fold', IfThenElse(and_(totalPotLE(ARG1, 13), lowestCardLE(ARG0, 13)), 'fold', IfThenElse(totalPotGE(ARG1, 15), 'raise', 'raise')))
# -13.68615
# IfThenElse(and_(totalPotLE(ARG1, 2), cardDifferenceLE(ARG0, 7)), 'fold', IfThenElse(cardDifferenceGE(ARG0, 5), 'fold', IfThenElse(totalPotLE(ARG1, 10), 'check', 'raise')))
# -13.692225
# IfThenElse(and_(cardDifferenceLE(ARG0, 6), cardDifferenceGE(ARG0, 14)), 'fold', IfThenElse(cardDifferenceGE(ARG0, 9), 'fold', IfThenElse(lowestCardLE(ARG0, 14), 'fold', 'fold')))
# -13.696575
# IfThenElse(and_(cardDifferenceGE(ARG0, 6), totalPotGE(ARG1, 22)), 'raise', IfThenElse(totalPotGE(ARG1, 7), 'raise', IfThenElse(highestCardGE(ARG0, 11), 'fold', 'fold')))
# -13.697625
# IfThenElse(and_(totalPotLE(ARG1, 29), cardDifferenceLE(ARG0, 12)), 'fold', IfThenElse(totalPotGE(ARG1, 6), 'fold', IfThenElse(hasDoubles(ARG0), 'raise', 'raise')))
# -13.7001
# IfThenElse(cardDifferenceLE(ARG0, 8), 'fold', IfThenElse(and_(cardDifferenceGE(ARG0, 9), highestCardGE(ARG0, 5)), 'fold', IfThenElse(hasDoubles(ARG0), 'fold', 'check')))
# -13.700475
# IfThenElse(and_(isSameSuit(ARG0), lowestCardGE(ARG0, 14)), 'fold', IfThenElse(cardDifferenceGE(ARG0, 10), 'fold', IfThenElse(hasDoubles(ARG0), 'fold', 'fold')))
# -13.70775
# IfThenElse(and_(totalPotGE(ARG1, 10), totalPotLE(ARG1, 6)), 'fold', IfThenElse(highestCardLE(ARG0, 3), 'fold', IfThenElse(totalPotGE(ARG1, 6), 'fold', 'fold')))
# -13.712175
# IfThenElse(totalPotLE(ARG1, 13), 'fold', IfThenElse(highestCardGE(ARG0, 3), 'check', IfThenElse(and_(cardDifferenceLE(ARG0, 14), totalPotLE(ARG1, 11)), 'fold', 'check')))
# -13.712925
# IfThenElse(highestCardGE(ARG0, 4), 'fold', IfThenElse(and_(lowestCardLE(ARG0, 11), highestCardLE(ARG0, 14)), 'raise', IfThenElse(lowestCardLE(ARG0, 11), 'raise', 'fold')))
# -13.750475
# IfThenElse(and_(hasDoubles(ARG0), lowestCardGE(ARG0, 10)), 'check', IfThenElse(totalPotGE(ARG1, 21), 'fold', IfThenElse(lowestCardLE(ARG0, 14), 'raise', 'check')))
# -14.723075
# IfThenElse(totalPotGE(ARG1, 27), 'fold', IfThenElse(highestCardGE(ARG0, 7), 'fold', IfThenElse(and_(totalPotGE(ARG1, 25), isSameSuit(ARG0)), 'fold', 'raise')))
# -14.931125
# IfThenElse(highestCardLE(ARG0, 9), 'raise', IfThenElse(totalPotGE(ARG1, 10), 'check', IfThenElse(and_(totalPotLE(ARG1, 9), isSameSuit(ARG0)), 'fold', 'fold')))
# -14.94635
